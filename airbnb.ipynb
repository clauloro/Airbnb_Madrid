# %% [markdown]
# # Análisis de datos

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import pandas as pd

df = pd.read_csv('madridairbnb.csv', error_bad_lines=False)

df
# Out:
# C:\Users\Claudia\AppData\Local\Temp\ipykernel_3020\3674196756.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('madridairbnb.csv', error_bad_lines=False)
# Skipping line 3: expected 70 fields, saw 109
# Skipping line 4: expected 70 fields, saw 104
# Skipping line 5: expected 70 fields, saw 74
# Skipping line 10: expected 70 fields, saw 149
# Skipping line 12: expected 70 fields, saw 127
# Skipping line 13: expected 70 fields, saw 79
# Skipping line 14: expected 70 fields, saw 85
# Skipping line 15: expected 70 fields, saw 102
# Skipping line 16: expected 70 fields, saw 87
# Skipping line 18: expected 70 fields, saw 90
# Skipping line 22: expected 70 fields, saw 103
# Skipping line 23: expected 70 fields, saw 82
# Skipping line 24: expected 70 fields, saw 114
# Skipping line 25: expected 70 fields, saw 77
# Skipping line 26: expected 70 fields, saw 123
# ...
